# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Anuj
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
fake = pd.read_csv(r"C:\Users\Anuj Kumar\OneDrive\Desktop\Fake_News_Detection\datasets\Fake.csv")
real = pd.read_csv(r"C:\Users\Anuj Kumar\OneDrive\Desktop\Fake_News_Detection\datasets\True.csv")

# %%
df1 = fake.copy()
df2 = real.copy()

# %%
df1.info()
df2.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  str
#  1   text     23481 non-null  str
#  2   subject  23481 non-null  str
#  3   date     23481 non-null  str
# dtypes: str(4)
# memory usage: 733.9 KB
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
ps = PorterStemmer()

# %%
def text_cleaning(text):
    text = text.lower()

    text = re.sub(r'[^a-zA-Z]',' ',text)
    stop_words = set(stopwords.words('english'))

    words = text.split()
    sentence = []
    for word in  words:
        if word not in stop_words:
            sentence.append(ps.stem(word))

    return " ".join(sentence)

# %%
df1["label"] = 0
df2["label"] = 1

# %%
df = pd.concat([df1,df2],axis=0)

# %%
df.shape
# Out:
# (44898, 5)

# %%
# shuffling rows
df = df.sample(frac=1).reset_index(drop=True)

# %%
df['content'] = df['title']+" "+df["text"]

# %%
df.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'label', 'content'], dtype='str')

# %%
df["content"]=df["content"].apply(text_cleaning)

# %%
df['content'].head()
# Out:
# 0    qatari emir attend gulf summit despit row fore...
# 1    racist go crazi samuel l jackson trash trump j...
# 2    gari johnson prove mental ill video proof gari...
# 3    low key trump end social media silenc reuter s...
# 4    break news man laptop american airlin flight h...
# Name: content, dtype: str

# %%
df.head()
# Out:
#                                                title  \
# 0  Qatari emir to attend Gulf summit despite row:...
# 1   Racists Go CRAZY after Samuel L Jackson Trash...
# 2  GARY JOHNSON Just Proved He Is MENTALLY ILL! [...
# 3          A low-key Trump ends social media silence
# 4  BREAKING NEWS: Man With Laptop On American Air...
#
#                                                 text       subject  \
# 0  DOHA (Reuters) - Qatari Emir Sheikh Tamim bin ...     worldnews
# 1  The racists came out in full force when Jimmy ...          News
# 2  More proof Gary Johnson is mentally ill.I was ...      politics
# 3  (Reuters) - After what seemed like a very long...  politicsNews
# 4  Tick tock. America will now wait until conserv...     left-news
#
#                 date  label                                            content
# 0  December 3, 2017       1  qatari emir attend gulf summit despit row fore...
# 1    January 3, 2016      0  racist go crazi samuel l jackson trash trump j...
# 2       Sep 23, 2016      0  gari johnson prove mental ill video proof gari...
# 3  February 2, 2016       1  low key trump end social media silenc reuter s...
# 4       May 19, 2017      0  break news man laptop american airlin flight h...
